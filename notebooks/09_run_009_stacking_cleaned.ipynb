# %% [markdown]
# # 009 - Stacking + Advanced Cleaning (Le "All-In")
#
# ## Objectif
# Combiner l'architecture gagnante (Stacking RUN 006) avec la qualité de données du RUN 008 (Cleaning & Outliers).
#
# ## Architecture
# 1. **Preprocessing** :
#     - Retrait Outliers (>4000sqft) sur Train.
#     - Imputation métier (None/0) + Feature Engineering (TotalSF).
# 2. **Base Models** (Niveau 1) :
#     - **XGBoost** (Tuned)
#     - **CatBoost** (Différente gestion des catégories)
#     - **ExtraTrees** (Diversité)
# 3. **Meta Model** (Niveau 2) :
#     - **Ridge Regression**
#
# ## Hypothèse
# Devrait battre le RUN 008 (13692) et le RUN 006 (13868). Objectif < 13600 ?

# %%
# !python ../src/run_009_stacking_cleaned.py
